# %%
# A股-股票市场总貌-上海证券交易所
import akshare as ak
stock_sse_summary_df = ak.stock_sse_summary()
print(stock_sse_summary_df)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 2
#       1 # A股-股票市场总貌-上海证券交易所
# ----> 2 import akshare as ak
#       3 stock_sse_summary_df = ak.stock_sse_summary()
#       4 print(stock_sse_summary_df)
#
# File C:\runtime\python\python310\lib\site-packages\akshare\__init__.py:3803
#    3795 from akshare.stock_feature.stock_analyst_em import (
#    3796     stock_analyst_detail_em,
#    3797     stock_analyst_rank_em,
#    3798 )
#    3800 """
#    3801 sgx futures data
#    3802 """
# -> 3803 from akshare.futures.futures_sgx_daily import futures_sgx_daily
#    3805 """
#    3806 currency interface
#    3807 """
#    3808 from akshare.currency.currency import (
#    3809     currency_convert,
#    3810     currency_currencies,
#    (...)
#    3813     currency_time_series,
#    3814 )
#
# ...

# %%
# A股-股票市场总貌-深圳证券交易所
import akshare as ak
stock_szse_summary_df = ak.stock_szse_summary(date="20230125")
print(stock_szse_summary_df)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 2
#       1 # A股-股票市场总貌-深圳证券交易所
# ----> 2 import akshare as ak
#       3 stock_szse_summary_df = ak.stock_szse_summary(date="20230125")
#       4 print(stock_szse_summary_df)
#
# File C:\runtime\python\python310\lib\site-packages\akshare\__init__.py:3803
#    3795 from akshare.stock_feature.stock_analyst_em import (
#    3796     stock_analyst_detail_em,
#    3797     stock_analyst_rank_em,
#    3798 )
#    3800 """
#    3801 sgx futures data
#    3802 """
# -> 3803 from akshare.futures.futures_sgx_daily import futures_sgx_daily
#    3805 """
#    3806 currency interface
#    3807 """
#    3808 from akshare.currency.currency import (
#    3809     currency_convert,
#    3810     currency_currencies,
#    (...)
#    3813     currency_time_series,
#    3814 )
#
# ...

# %%
# A股实时行情数据
import akshare as ak
stock_zh_a_spot_df = ak.stock_zh_a_spot()
print(stock_zh_a_spot_df)
# Out:
#             代码    名称     最新价   涨跌额    涨跌幅      买入      卖出      昨收      今开  \
# 0     bj430017  星昊医药   15.10 -0.30 -1.948   15.09   15.10   15.40   15.43
# 1     bj430047  诺思兰德   14.31 -0.40 -2.719   14.31   14.32   14.71   14.80
# 2     bj430090  同辉信息    6.98 -0.39 -5.292    6.97    6.98    7.37    7.27
# 3     bj430139  华岭股份   26.30 -1.46 -5.259   26.30   26.31   27.76   27.22
# 4     bj430198  微创光电   13.80 -0.27 -1.919   13.80   13.81   14.07   14.23
# ...        ...   ...     ...   ...    ...     ...     ...     ...     ...
# 5389  sz301626  苏州天脉   90.00 -5.02 -5.283   89.55   90.00   95.02   94.01
# 5390  sz301628  强达电路   93.24 -3.26 -3.378   93.24   93.25   96.50   95.19
# 5391  sz301631  壹连科技  129.18  0.20  0.155  129.18  129.30  128.98  129.13
# 5392  sz301633  港迪技术   83.07 -1.64 -1.936   83.06   83.07   84.71   84.29
# 5393  sz302132  中航成飞   61.20 -1.61 -2.563   61.20   61.21   62.81   62.25
#
#           最高      最低         成交量          成交额       时间戳
# ...

# %%
import akshare as ak
stock_zh_a_tick_tx_df = ak.stock_zh_a_tick_tx(symbol="sh600848", trade_date="20191011")
print(stock_zh_a_tick_tx_df)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 import akshare as ak
#       2 stock_zh_a_tick_tx_df = ak.stock_zh_a_tick_tx(symbol="sh600848", trade_date="20191011")
#       3 print(stock_zh_a_tick_tx_df)
#
# File C:\runtime\python\python310\lib\site-packages\akshare\__init__.py:3803
#    3795 from akshare.stock_feature.stock_analyst_em import (
#    3796     stock_analyst_detail_em,
#    3797     stock_analyst_rank_em,
#    3798 )
#    3800 """
#    3801 sgx futures data
#    3802 """
# -> 3803 from akshare.futures.futures_sgx_daily import futures_sgx_daily
#    3805 """
#    3806 currency interface
#    3807 """
#    3808 from akshare.currency.currency import (
#    3809     currency_convert,
#    3810     currency_currencies,
#    (...)
#    3813     currency_time_series,
#    3814 )
#
# ...

# %%
from mootdx.quotes import Quotes

client = Quotes.factory(market='std', multithread=True, heartbeat=True, bestip=False, timeout=15)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 from mootdx.quotes import Quotes
# ----> 3 client = Quotes.factory(market='std', multithread=True, heartbeat=True, bestip=False, timeout=15)
#
# File C:\runtime\python\python312\Lib\site-packages\mootdx\quotes.py:44, in Quotes.factory(market, **kwargs)
#      41 if market == 'ext':
#      42     return ExtQuotes(**kwargs)
# ---> 44 return StdQuotes(**kwargs)
#
# File C:\runtime\python\python312\Lib\site-packages\mootdx\quotes.py:154, in StdQuotes.__init__(self, server, bestip, timeout, heartbeat, auto_retry, raise_exception, **kwargs)
#     151     self.server = config.get('BESTIP').get('HQ', default)
#     153 logger.debug(f'server: {self.server}')
# --> 154 ip, port = self.server
#     156 self.client = TdxHq_API(heartbeat=heartbeat, auto_retry=auto_retry, raise_exception=raise_exception)
# ...

# %%
client.quotes(symbol=["000001", "600300"])

# %%
from mootdx.quotes import Quotes
from mootdx import consts

client = Quotes.factory(market='std')
symbol = client.stocks(market=consts.MARKET_SH)
print(symbol)

# %%
# 基本面数据
# 1. 财务摘要
import akshare as ak
stock_financial_abstract_df = ak.stock_financial_abstract(stock="603126")
print(stock_financial_abstract_df)
data = ak.stock_analyst_rank_em()
print(data)

# %%
import akshare as ak
stock_financial_analysis_indicator_df = ak.stock_financial_analysis_indicator(symbol="603126")
print(stock_financial_analysis_indicator_df)

# %%
import akshare as ak

stock_industry_sina_df = ak.stock_sector_spot(indicator="新浪行业")
print(stock_industry_sina_df)

# %%
import akshare as ak

stock_sector_detail_df = ak.stock_sector_detail(sector="new_jdly")
print(stock_sector_detail_df)

# %%
import akshare as ak
df = ak.stock_gdfx_free_holding_detail_em(date="20221231")
print(df)

# %%
import akshare as ak

stock_zh_ah_name_dict = ak.stock_zh_ah_name()
print(stock_zh_ah_name_dict)

# %%
import akshare as ak
stock_notice_report_df = ak.stock_notice_report(symbol='财务报告', date="20230501")
print(stock_notice_report_df)

# %%
import akshare as ak
df = ak.stock_yjyg_em(date="2023-03-31")
print(df)

# %%
import akshare as ak
df=ak.stock_info_a_code_name()
print(df)

# %%
import akshare as ak
stock_individual_fund_flow_df = ak.stock_individual_fund_flow(stock="600977", market="sh")
print(stock_individual_fund_flow_df)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 import akshare as ak
#       2 stock_individual_fund_flow_df = ak.stock_individual_fund_flow(stock="600977", market="sh")
#       3 print(stock_individual_fund_flow_df)
#
# File C:\runtime\python\python310\lib\site-packages\akshare\__init__.py:3803
#    3795 from akshare.stock_feature.stock_analyst_em import (
#    3796     stock_analyst_detail_em,
#    3797     stock_analyst_rank_em,
#    3798 )
#    3800 """
#    3801 sgx futures data
#    3802 """
# -> 3803 from akshare.futures.futures_sgx_daily import futures_sgx_daily
#    3805 """
#    3806 currency interface
#    3807 """
#    3808 from akshare.currency.currency import (
#    3809     currency_convert,
#    3810     currency_currencies,
#    (...)
#    3813     currency_time_series,
#    3814 )
#
# ...

# %%
import akshare as ak
#获取实时行悟数据
snapshots = ak.stock_zh_a_spot_em()
print(snapshots)
print(len(snapshots))
# Out:
#      序号      代码    名称    最新价    涨跌幅    涨跌额      成交量           成交额     振幅  \
# 0     1  832171  志晟信息  38.87  30.00   8.97   245576  8.818749e+08  29.46
# 1     2  836547  无锡晶海  27.78  30.00   6.41   102275  2.543383e+08  30.23
# 2     3  831689   克莱特  44.96  29.98  10.37   158903  6.450379e+08  23.91
# 3     4  430564  天润科技  30.23  29.97   6.97   111015  3.213873e+08  29.97
# 4     5  835892  中科美菱  23.34  29.96   5.38   139980  2.948995e+08  30.90
# ..  ...     ...   ...    ...    ...    ...      ...           ...    ...
# 95   96  603168  莎普爱思   7.81  10.00   0.71   412733  3.178207e+08  10.99
# 96   97  600590  泰豪科技  11.88  10.00   1.08  1625777  1.781379e+09  18.98
# 97   98  600490  鹏欣资源   3.96  10.00   0.36  2493828  9.710875e+08   6.67
# 98   99  600419  天润乳业  10.89  10.00   0.99   246343  2.606142e+08   8.28
# 99  100  600382  广东明珠   4.95  10.00   0.45   204598  9.794990e+07  10.00
#
#        最高  ...    量比    换手率  市盈率-动态    市净率          总市值         流通市值   涨速  \
# ...

# %%
import akshare as ak
stock_individual_fund_flow_df = ak.stock_individual_fund_flow(stock="600094", market="sh")
print(stock_individual_fund_flow_df)
# Out:
#              日期   收盘价   涨跌幅   主力净流入-净额  主力净流入-净占比  超大单净流入-净额  超大单净流入-净占比  \
# 0    2024-09-10  3.10 -0.96 -2855107.0      -5.70  -575229.0       -1.15
# 1    2024-09-11  3.11  0.32 -1001218.0      -3.58  -574726.0       -2.05
# 2    2024-09-12  3.15  1.29   762079.0       2.21    56583.0        0.16
# 3    2024-09-13  3.15  0.00   281683.0       0.95    82576.0        0.28
# 4    2024-09-18  3.20  1.59  1866172.0       4.25   264319.0        0.60
# ..          ...   ...   ...        ...        ...        ...         ...
# 116  2025-03-11  3.52  1.73  7168266.0       8.19  2309426.0        2.64
# 117  2025-03-12  3.55  0.85  2632281.0       2.12 -1910921.0       -1.54
# 118  2025-03-13  3.47 -2.25 -2979006.0      -3.81   -42561.0       -0.05
# 119  2025-03-14  3.49  0.58 -4481921.0      -6.00 -1983254.0       -2.66
# 120  2025-03-17  3.48 -0.29 -5157873.0      -7.03 -3684110.0       -5.02
#
#       大单净流入-净额  大单净流入-净占比   中单净流入-净额  中单净流入-净占比   小单净流入-净额  小单净流入-净占比
# ...
