# %%
from numpy import square
import numpy as np
from sklearn import linear_model
#首先定义一个线性回归对象
lr=linear_model.lineregression()
#定义数据集
x=np.array([150,200,250,300,350,400,600])
y=np.array([6450,7450,8450,9450,11450,15450,18450])
#训练模型
lr.fit(square.reshape(-1,1),price)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 5
#       3 from sklearn import linear_model
#       4 #首先定义一个线性回归对象
# ----> 5 lr=linear_model.lineregression()
#       6 #定义数据集
#       7 x=np.array([150,200,250,300,350,400,600])
#
# AttributeError: module 'sklearn.linear_model' has no attribute 'lineregression'
