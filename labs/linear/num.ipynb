# %%
# 使用内置 round 函数
print(round(9.825, 2))  # 输出 9.82（存在浮点精度问题）
print(round(2.675, 2))  # 输出 2.67（经典精度陷阱）
# Out:
# 9.82
# 2.67

# %%
# 使用内置 round 函数
print(round(9.825, 2))  # 输出 9.82（存在浮点精度问题）
print(round(2.675, 2))  # 输出 2.67（经典精度陷阱）
print(34423.125000, round(34423.125000, 2))
# Out:
# 9.82
# 2.67
# 34423.125 34423.12
