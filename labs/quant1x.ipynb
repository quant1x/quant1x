# %%
from quant1x import __version__
print(__version__)
from quant1x.contrib.data.tdx.datasource import TdxDataSource
D = TdxDataSource()
df = D.klines('600600')
print(df)
# Out:
# 0.7.6.dev135
# 2026-02-05 16:55:48.204 | INFO     | quant1x.log.logger:<module>:62 - 日志文件路径: C:\Users\wangfeng\.q1x-py/logs/ipykernel_launcher.log
# Loading Xdxr data from C:\Users\wangfeng\.q1x-py/xdxr/sh600600.csv
# ...
