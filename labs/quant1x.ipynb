# %%
from quant1x import __version__
print(__version__)
from quant1x.contrib.data.tdx.datasource import TdxDataSource
D = TdxDataSource()
df = D.klines('600178')
print(df)
# Out:
# 0.7.6.dev135
# 2026-02-23 09:24:37.909 | INFO     | quant1x.log.logger:<module>:64 - 日志文件路径: C:\Users\wangfeng\.q1x-py/logs/ipykernel_launcher.log
# 2026-02-23 09:24:38.380 | DEBUG    | quant1x.data.meta.calendar:initialize:213 - 交易日历单例已初始化
# 2026-02-23 09:24:38.380 | DEBUG    | quant1x.runtime.once:do:48 - [calendar_init] Executing callback
# 2026-02-23 09:24:38.382 | DEBUG    | quant1x.data.meta.calendar:_load_calendar_data:230 - 交易日历缓存文件过期，执行更新
# 2026-02-23 09:24:38.383 | WARNING  | quant1x.data.meta.calendar:_update_calendar:70 - 更新交易日历: 下载并缓存到 C:\Users\wangfeng\.q1x-py\meta\calendar
# 2026-02-23 09:24:38.451 | DEBUG    | quant1x.data.meta.calendar:_load_calendar_data:239 - 加载交易日历缓存文件到内存
# 2026-02-23 09:24:38.578 | DEBUG    | quant1x.data.meta.calendar:_load_calendar_data:271 - 交易日历加载完成，共 8797 个交易日
# 2026-02-23 09:24:38.579 | DEBUG    | quant1x.contrib.data.tdx.kline_raw:update:326 - [basedata::BarRaw] [sh600178]: from 1990-12-19 to 2026-02-23
# ...
