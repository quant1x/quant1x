# %%
from quant1x import __version__
from quant1x.config import config
config.debug = False
print(__version__)
from quant1x.contrib.data.tdx.datasource import TdxDataSource
D = TdxDataSource()
df = D.klines('hsi.hk')
print(df)
# Out:
# 2026-02-24 10:53:55.640 | INFO     | quant1x.log.logger:<module>:65 - 日志文件路径: C:\Users\wangfeng\.q1x-py/logs/ipykernel_launcher.log
# 0.7.6.dev135
# 2026-02-24 10:53:56.065 | DEBUG    | quant1x.data.meta.calendar:initialize:213 - 交易日历单例已初始化
# 2026-02-24 10:53:56.065 | DEBUG    | quant1x.runtime.once:do:48 - [calendar_init] Executing callback
# 2026-02-24 10:53:56.066 | DEBUG    | quant1x.data.meta.calendar:_load_calendar_data:237 - 交易日历缓存文件未过期，跳过更新
# 2026-02-24 10:53:56.066 | DEBUG    | quant1x.data.meta.calendar:_load_calendar_data:239 - 加载交易日历缓存文件到内存
# 2026-02-24 10:53:56.194 | DEBUG    | quant1x.data.meta.calendar:_load_calendar_data:271 - 交易日历加载完成，共 8797 个交易日
# 2026-02-24 10:53:56.194 | DEBUG    | quant1x.contrib.data.tdx.datasource:klines:222 - Getting klines for hsi.hk as of 2026-02-24
# 2026-02-24 10:53:56.195 | DEBUG    | quant1x.runtime.once:do:48 - [tdx_security_init] Executing callback
# ...
