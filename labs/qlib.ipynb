# %%
from qlib import init
from qlib.data import D
from qlib.constant import REG_CN
init()
# 1. 获取中证500成分股
csi500_stocks = D.instruments('csi500')
print(f"CSI500 股票数量: {len(list(csi500_stocks))}")
print(csi500_stocks)

# 2. 获取特定时间段的历史成分
hist_stocks = D.list_instruments(
    instruments='csi300',
    start_time='2022-01-01',
    end_time='2022-12-31'
)

# 3. 获取股票详细信息
stock_info = D.instrument('SH600519').info()  # 贵州茅台
print(stock_info)
# Out:
# [12732:MainThread](2026-06-21 07:45:18,588) INFO - qlib.Initialization - [config.py:452] - default_conf: client.
# [12732:MainThread](2026-06-21 07:45:18,590) WARNING - qlib.Initialization - [__init__.py:65] - auto_path is False, please make sure None is mounted
# [12732:MainThread](2026-06-21 07:45:18,590) INFO - qlib.Initialization - [__init__.py:75] - qlib successfully initialized based on client settings.
# [12732:MainThread](2026-06-21 07:45:18,590) INFO - qlib.Initialization - [__init__.py:77] - data_path={'__DEFAULT_FREQ': WindowsPath('C:/Users/wangfeng/.qlib/qlib_data/cn_data')}
# CSI500 股票数量: 2
# {'market': 'csi500', 'filter_pipe': []}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 11
#       8 print(csi500_stocks)
#      10 # 2. 获取特定时间段的历史成分
# ---> 11 hist_stocks = D.list_instruments(
#      12     instruments='csi300',
# ...
