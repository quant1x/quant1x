# %%
from futu import *
quote_ctx = OpenQuoteContext(host='127.0.0.1', port=11111)
ret, data = quote_ctx.get_stock_basicinfo(Market.HK, SecurityType.STOCK)
if ret == RET_OK:
    print(data)
else:
    print('error:', data)
print('******************************************')
ret, data = quote_ctx.get_stock_basicinfo(Market.HK, SecurityType.STOCK, ['HK.06998', 'HK.00700'])
if ret == RET_OK:
    print(data)
    print(data['name'][0])  # 取第一条的股票名称
    print(data['name'].values.tolist())  # 转为 list
else:
    print('error:', data)
quote_ctx.close()  # 结束后记得关闭当条连接，防止连接条数用尽
# Out:
# 2023-02-21 06:36:35,844 | 80202 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=1; msg=ECONNREFUSED
# 2023-02-21 06:36:43,850 | 80202 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=2; msg=ECONNREFUSED
# 2023-02-21 06:36:51,858 | 80202 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=3; msg=ECONNREFUSED
# 2023-02-21 06:36:59,865 | 80202 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=4; msg=ECONNREFUSED
# 2023-02-21 06:37:07,869 | 80202 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=5; msg=ECONNREFUSED
# 2023-02-21 06:37:15,899 | 80202 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=6, host=127.0.0.1, port=11111, user_id=10194373
#            code         name  lot_size stock_type stock_child_type  \
# 0      HK.00001           长和       500      STOCK              N/A
# 1      HK.00002         中电控股       500      STOCK              N/A
# 2      HK.00003       香港中华煤气      1000      STOCK              N/A
# 3      HK.00004        九龙仓集团      1000      STOCK              N/A
# 4      HK.00005         汇丰控股       400      STOCK              N/A
# ...         ...          ...       ...        ...              ...
# 3057  HK.810458   赛目科技(临时代码)         0      STOCK              N/A
# 3058  HK.810459  陆道培医疗(临时代码)         0      STOCK              N/A
# 3059  HK.810460   珍酒李渡(临时代码)         0      STOCK              N/A
# 3060  HK.810461    德生堂(临时代码)         0      STOCK              N/A
# 3061  HK.810462   泰丰文化(临时代码)         0      STOCK              N/A
#
#      stock_owner option_type strike_time strike_price suspension listing_date  \
# 0                        N/A                      N/A        N/A   2015-03-18
# 1                        N/A                      N/A        N/A   1970-01-01
# 2                        N/A                      N/A        N/A   1970-01-01
# 3                        N/A                      N/A        N/A   1970-01-01
# 4                        N/A                      N/A        N/A   1970-01-01
# ...          ...         ...         ...          ...        ...          ...
# 3057                     N/A                      N/A        N/A   1970-01-01
# 3058                     N/A                      N/A        N/A   1970-01-01
# 3059                     N/A                      N/A        N/A   1970-01-01
# 3060                     N/A                      N/A        N/A   1970-01-01
# 3061                     N/A                      N/A        N/A   1970-01-01
#
#            stock_id  delisting index_option_type  main_contract  \
# 0     4440996184065      False               N/A          False
# 1                 2      False               N/A          False
# 2                 3      False               N/A          False
# 3                 4      False               N/A          False
# 4                 5      False               N/A          False
# ...             ...        ...               ...            ...
# 3057         810458      False               N/A          False
# 3058         810459      False               N/A          False
# 3059         810460      False               N/A          False
# 3060         810461      False               N/A          False
# 3061         810462      False               N/A          False
#
#      last_trade_time exchange_type
# 0                     HK_MAINBOARD
# 1                     HK_MAINBOARD
# 2                     HK_MAINBOARD
# 3                     HK_MAINBOARD
# 4                     HK_MAINBOARD
# ...              ...           ...
# 3057                  HK_MAINBOARD
# 3058                  HK_MAINBOARD
# 3059                  HK_MAINBOARD
# 3060                  HK_MAINBOARD
# 3061                  HK_MAINBOARD
#
# [3062 rows x 17 columns]
# ******************************************
#        code    name  lot_size stock_type stock_child_type stock_owner  \
# 0  HK.06998  嘉和生物-B       500      STOCK              N/A
# 1  HK.00700    腾讯控股       100      STOCK              N/A
#
#   option_type strike_time strike_price suspension listing_date  \
# 0         N/A                      N/A        N/A   2020-10-07
# 1         N/A                      N/A        N/A   2004-06-16
#
#          stock_id  delisting index_option_type  main_contract last_trade_time  \
# 0  79572859099990      False               N/A          False
# 1  54047868453564      False               N/A          False
#
#   exchange_type
# 0  HK_MAINBOARD
# 1  HK_MAINBOARD
# 嘉和生物-B
# ['嘉和生物-B', '腾讯控股']
# 2023-02-21 06:37:16,423 | 80202 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=6
